# %% [markdown]
# # Creates all maximal required load profiles with tsorb and tsib

# %%
import os
import time
import datetime

# %%
import pandas as pd

# %%
import tsib

# %%
import multiprocessing as mp

# %% [markdown]
# Number of household size

# %%
HH_SIZE = [1,2,3,4,5]

# %% [markdown]
# Get time series for Potsdam

# %%
weather, loc = tsib.readTRY(try_num=4)

# %% [markdown]
# Get a time dataframe for performance checking

# %%
timeFrame = pd.DataFrame(
    {'Start time': pd.NaT, 'End time': pd.NaT, 'Duration [s]': 0.0},
    index=HH_SIZE,
)

# %% [markdown]
# Generate for all seeds the profiles, if not existant

# %%
SEEDS = [x for x in range(tsib.buildingmodel.TOTAL_PROFILE_NUM+1)]

# %%
for n_persons in HH_SIZE:
    # get starttime
    startTime = time.time()
    timeFrame.loc[n_persons,'Start time'] = datetime.datetime.now()
    
    tsib.getHouseholdProfiles(n_persons,
                               weather, '4', seeds=SEEDS,
                               ignore_weather=True,
                               mean_load=True,
                              cores = mp.cpu_count() - 2)
    
    # get endtime
    endTime = time.time()
    timeFrame.loc[n_persons,'End time'] = datetime.datetime.now()
    timeFrame.loc[n_persons,'Duration [s]'] = endTime-startTime
    
    print('FINISHED - Duration for '+ str(n_persons) + ' persons: ' + str(endTime-startTime))
# Out:
# Start 12 processes, round 1 of 2
#   Process 1
#   Process 2
#   Process 3
#   Process 4
#   Process 5
#   Process 6
#   Process 7
#   Process 8
#   Process 9
#   Process 10
#   Process 11
#   Process 12
# - closed the round
# Start 9 processes, round 2 of 2
#   Process 1
#   Process 2
#   Process 3
#   Process 4
#   Process 5
#   Process 6
#   Process 7
#   Process 8
#   Process 9
# - closed the round
# FINISHED - Duration for 1 persons: 131.93356800079346
# Start 12 processes, round 1 of 2
#   Process 1
#   Process 2
#   Process 3
#   Process 4
#   Process 5
#   Process 6
#   Process 7
#   Process 8
#   Process 9
#   Process 10
#   Process 11
#   Process 12
# - closed the round
# Start 5 processes, round 2 of 2
#   Process 1
#   Process 2
#   Process 3
#   Process 4
#   Process 5
# - closed the round
# FINISHED - Duration for 2 persons: 139.46257972717285
# Start 12 processes, round 1 of 2
#   Process 1
#   Process 2
#   Process 3
#   Process 4
#   Process 5
#   Process 6
#   Process 7
#   Process 8
#   Process 9
#   Process 10
#   Process 11
#   Process 12
# - closed the round
# Start 9 processes, round 2 of 2
#   Process 1
#   Process 2
#   Process 3
#   Process 4
#   Process 5
#   Process 6
#   Process 7
#   Process 8
#   Process 9
# - closed the round
# FINISHED - Duration for 3 persons: 160.88334226608276
# Start 12 processes, round 1 of 2
#   Process 1
#   Process 2
#   Process 3
#   Process 4
#   Process 5
#   Process 6
#   Process 7
#   Process 8
#   Process 9
#   Process 10
#   Process 11
#   Process 12
# - closed the round
# Start 9 processes, round 2 of 2
#   Process 1
#   Process 2
#   Process 3
#   Process 4
#   Process 5
#   Process 6
#   Process 7
#   Process 8
#   Process 9
# - closed the round
# FINISHED - Duration for 4 persons: 142.54187726974487
# Start 12 processes, round 1 of 2
#   Process 1
#   Process 2
#   Process 3
#   Process 4
#   Process 5
#   Process 6
#   Process 7
#   Process 8
#   Process 9
#   Process 10
#   Process 11
#   Process 12
# - closed the round
# Start 9 processes, round 2 of 2
#   Process 1
#   Process 2
#   Process 3
#   Process 4
#   Process 5
#   Process 6
#   Process 7
#   Process 8
#   Process 9
# - closed the round
# FINISHED - Duration for 5 persons: 142.63854265213013

# %%
timeFrame.to_csv(os.path.join(os.getcwd(),'timeDuration.csv'))
