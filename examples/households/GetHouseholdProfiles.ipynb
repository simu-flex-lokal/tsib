# %% [markdown]
# ## Create household profiles in parallel
#
# Author: Leander Kotzur

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Import the profile generation module

# %%
import tsib

# %% [markdown]
# Create profiles for three, three person households

# %%
res = tsib.simHouseholdsParallel(3,2010, 3, cores = 4, get_hot_water = True)
# Out:
# Start 3 processes, round 1 of 1
#   Process 1
#   Process 2
#   Process 3
# - closed the round

# %%
res
# Out:
#                             Load  AppHeatGain  OccActive  OccNotActive  \
# 2010-01-01 00:00:00   183.836684    57.822917          2             6
# 2010-01-01 01:00:00   504.648397   265.452748          1             7
# 2010-01-01 02:00:00   180.411155    54.500155          0             9
# 2010-01-01 03:00:00   180.411155    54.500155          0             9
# 2010-01-01 04:00:00   180.411155    54.500155          0             9
# ...                          ...          ...        ...           ...
# 2010-12-31 19:00:00  3869.643652   948.406887          7             0
# 2010-12-31 20:00:00  2470.157669   819.404191          8             0
# 2010-12-31 21:00:00  1094.522062   576.691410          5             0
# 2010-12-31 22:00:00  1447.754827   851.259314          6             1
# 2010-12-31 23:00:00  1420.866585   885.485993          5             3
#
#                         HotWater
# 2010-01-01 00:00:00     0.000000
# 2010-01-01 01:00:00  2021.647068
# 2010-01-01 02:00:00     0.000000
# 2010-01-01 03:00:00     0.000000
# 2010-01-01 04:00:00     0.000000
# ...                          ...
# 2010-12-31 19:00:00     0.000000
# 2010-12-31 20:00:00  1845.884050
# 2010-12-31 21:00:00  1845.884050
# 2010-12-31 22:00:00     0.000000
# 2010-12-31 23:00:00  4129.653607
#
# [8760 rows x 5 columns]
